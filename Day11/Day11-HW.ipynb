# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 11
# ---------------------------------------
#
# GOALS:
#
# 1. Understand Causal vs Experimental Studies
# 2. Do a more free form data analysis
# 3. Start doing your ethics reading
#
# ----------------------------------------------------------
#
# This homework has **2 questions**, **10 exercises** and **1 essay response**.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# This stops a few warning messages from showing
pd.options.mode.chained_assignment = None 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
file_name = 'data/yougov-climate.csv'
DF = pd.read_csv(file_name,index_col=0)
DF
# Out:
#          The climate is changing and human activity is mainly responsible    \
# country
# GB                                                     833
# US                                                     507
#
#          The climate is changing and human activity is partly responsible, together with other factors    \
# country
# GB                                                     604
# US                                                     493
#
#          The climate is changing but human activity is not responsible at all    \
# country
# GB                                                      49
# US                                                     120
#
#          The climate is not changing    Don't know
# country
# GB                                  33         114
# US                                  80         133

# %% [markdown]
# In the lecture we analyzed the following questions for the first column in the data:
#
# ### First question:
#
# What percent of **all respondents** think the climate is changing and human activity is mainly responsible?
#
# ### Second question:
#
# What percent of **GB respondents** think the climate is changing and  human activity is mainly responsible?
#
# ### Third Question
#
# What percent of **US respondents** think the climate is changing and  human activity is mainly responsible?
#
# **Q1** Repeat the analysis from the lecture notes for one of the other columns/questions.
#
# 1. Percent total
# 2. Percent from GB
# 3. Percent from US
#
# Talk about the conditional probability in this case:
#
# eg. In a person is from ________ then there is a ________ probability that they believe _______. If a person answered _______ then they are more likley to be from ________.

# %% [markdown]
# ## Berkeley admission data example
#
# - Study carried out by the Graduate Division of the University of California, Berkeley in the early 70’s to evaluate whether there was a gender bias in graduate admissions.
# - The data come from six departments. For confidentiality we'll call them A-F.
# - We have information on whether the applicant was male or female and whether they were admitted or rejected. This is an old study so only two binary classifications were used.
#
# ### Here is the data

# %%
file_name = 'data/berkley.csv'
DF = pd.read_csv(file_name)
show(DF)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_396a3fd0_de25_4f95_afe3_52a17faa3d9c"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_396a3fd0_de25_4f95_afe3_52a17faa3d9c:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "classes": ["display", "nowrap"], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "text_in_header_can_be_selected": true, "order": [], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>Department</th>\n      <th>Male Yes</th>\n      <th>Male No</th>\n      <th>Female Yes</th>\n      <th>Female No</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"A\", 512, 313, 89, 19], [\"B\", 353, 207, 17, 8], [\"C\", 120, 205, 202, 391], [\"D\", 138, 279, 131, 244], [\"E\", 53, 138, 94, 299], [\"F\", 22, 351, 24, 317]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
DF_melt = pd.melt(DF,id_vars=['Department'],var_name='MF',value_name='Number')
DF_melt
# Out:
#    Department          MF  Number
# 0           A    Male Yes     512
# 1           B    Male Yes     353
# 2           C    Male Yes     120
# 3           D    Male Yes     138
# 4           E    Male Yes      53
# 5           F    Male Yes      22
# 6           A     Male No     313
# 7           B     Male No     207
# 8           C     Male No     205
# 9           D     Male No     279
# 10          E     Male No     138
# 11          F     Male No     351
# 12          A  Female Yes      89
# 13          B  Female Yes      17
# 14          C  Female Yes     202
# 15          D  Female Yes     131
# 16          E  Female Yes      94
# 17          F  Female Yes      24
# 18          A   Female No      19
# 19          B   Female No       8
# 20          C   Female No     391
# 21          D   Female No     244
# 22          E   Female No     299
# 23          F   Female No     317

# %%
DF_melt['gender'] = DF_melt['MF'].apply(lambda x: x.split(' ')[0]).copy()
DF_melt['admitted'] = DF_melt['MF'].apply(lambda x: x.split(' ')[1]).copy()

# %%
DF_melt
# Out:
#    Department          MF  Number  gender admitted
# 0           A    Male Yes     512    Male      Yes
# 1           B    Male Yes     353    Male      Yes
# 2           C    Male Yes     120    Male      Yes
# 3           D    Male Yes     138    Male      Yes
# 4           E    Male Yes      53    Male      Yes
# 5           F    Male Yes      22    Male      Yes
# 6           A     Male No     313    Male       No
# 7           B     Male No     207    Male       No
# 8           C     Male No     205    Male       No
# 9           D     Male No     279    Male       No
# 10          E     Male No     138    Male       No
# 11          F     Male No     351    Male       No
# 12          A  Female Yes      89  Female      Yes
# 13          B  Female Yes      17  Female      Yes
# 14          C  Female Yes     202  Female      Yes
# 15          D  Female Yes     131  Female      Yes
# 16          E  Female Yes      94  Female      Yes
# 17          F  Female Yes      24  Female      Yes
# 18          A   Female No      19  Female       No
# 19          B   Female No       8  Female       No
# 20          C   Female No     391  Female       No
# 21          D   Female No     244  Female       No
# 22          E   Female No     299  Female       No
# 23          F   Female No     317  Female       No

# %% [markdown]
# ### Gender distribution by department
#
# What can we say about the gender distribution if we look at the individual departments.
#
# Start with our original "melted" data frame:

# %% [markdown]
# #### Lets pivot!
#
# Pivot this data so that our departments become the column labels and our MF column becomes the index.

# %%
DF_dept = DF_melt.pivot(index='MF',columns='Department',values='Number')
DF_dept
# Out:
# Department    A    B    C    D    E    F
# MF
# Female No    19    8  391  244  299  317
# Female Yes   89   17  202  131   94   24
# Male No     313  207  205  279  138  351
# Male Yes    512  353  120  138   53   22

# %% [markdown]
# **Q2** Calculate the proportions for the other departments. We did department A in the lecture. You can use the code from the lecture or come up with your own way to do this. You can do this one by one or try using a FOR loop.
#
# Talk about what you see in these proportions. Which departments admit a large number of women? How do your number align with the visualization below?

# %%
# First, let's check if 'total' is a column or an index value
# Assuming 'total' is a column and 'GB' is in the index:
gb_respondants = DF.loc['GB', 'total']

# For the second line, the column name is very long and might have extra spaces
# Let's use a more reliable way to access it
column_name = "The climate is changing and human activity is mainly responsible"
GB_human_responsible = DF.loc['GB', column_name]

# Now calculate the ratio
GB_human_responsible/gb_respondants
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 # First, let's check if 'total' is a column or an index value
#       2 # Assuming 'total' is a column and 'GB' is in the index:
# ----> 3 gb_respondants = DF.loc['GB', 'total']
#       5 # For the second line, the column name is very long and might have extra spaces
#       6 # Let's use a more reliable way to access it
#       7 column_name = "The climate is changing and human activity is mainly responsible"
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4214, in DataFrame._get_value(self, index, col, takeable)
#    4211     series = self._ixs(col, axis=1)
#    4212     return series._values[index]
# -> 4214 series = self._get_item_cache(col)
#    4215 engine = self.index._engine
#    4217 if not isinstance(self.index, MultiIndex):
#    4218     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4219     #  results if our categories are integers that dont match our codes
#    4220     # IntervalIndex: IntervalTree has no get_loc
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4638, in DataFrame._get_item_cache(self, item)
#    4633 res = cache.get(item)
#    4634 if res is None:
#    4635     # All places that call _get_item_cache have unique columns,
#    4636     #  pending resolution of GH#33047
# -> 4638     loc = self.columns.get_loc(item)
#    4639     res = self._ixs(loc, axis=1)
#    4641     cache[item] = res
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'total'

# %% [markdown]
# ### Here is a plot of the proportions data

# %%
fig = px.histogram(DF_melt,
                   y='gender',
                   x='Number',
                   barnorm = "percent",
                   color='admitted',
                   facet_col='Department',
                   facet_col_wrap=2,
                   color_discrete_map = {'No':'#99d8c9','Yes':'#2ca25f'})

fig.for_each_annotation(lambda a: a.update(text=a.text.split("=")[1]))
fig.update_xaxes(title_text='')

fig.update_layout(title='Percent male and female applications',
                  title_x=0.5,
                  template="plotly_white",
                  xaxis_title="",
                  yaxis_title="Gender",
                  legend_title='Admitted',
                  autosize=False,
                  width=800,
                  height=500)

fig.show()

# %% [markdown]
# ------------------------
# ------------------------
#
# ## Homework - Exercises
#
# ** Homework content and data from Data Science in a Box - he-05-legos.Rmd
#
# This week we'll do some data gymnastics to refresh and review what we learned over the past few weeks using (**simulated**) data from Lego sales in 2018 for a sample of customers who bought Legos in the US. This is different than the data we used on the Exam!
#
#
# ### Data

# %%
file_name = 'data/lego-sales.csv'
DF = pd.read_csv(file_name)
DF
# Out:
#     first_name  last_name  age  phone_number  set_id   number  \
# 0     Kimberly  Beckstead   24  216-555-2549   24701    76062
# 1         Neel     Garvin   35  819-555-3189   25626    70595
# 2         Neel     Garvin   35  819-555-3189   24665    21031
# 3      Chelsea   Bouchard   41           NaN   24695    31048
# 4      Chelsea   Bouchard   41           NaN   25626    70595
# ..         ...        ...  ...           ...     ...      ...
# 615     Talise   Nieukirk   16  801-555-2343   24902    41556
# 616    Spencer     Morgan   28  784-555-3455   26041    41580
# 617    Spencer     Morgan   28  784-555-3455   26060  5005051
# 618     Amelia    Hageman   40  336-555-1950   24702    76063
# 619     Amelia    Hageman   40  336-555-1950   24720    10830
#
#                       theme              subtheme  year  \
# 0    DC Comics Super Heroes         Mighty Micros  2018
# 1                   Ninjago  Rise of the Villains  2018
# 2              Architecture                   NaN  2018
# 3                   Creator                   NaN  2018
# 4                   Ninjago  Rise of the Villains  2018
# ..                      ...                   ...   ...
# 615                  Mixels              Series 7  2018
# 616                  Mixels              Series 9  2018
# 617                    Gear         Digital Media  2018
# 618  DC Comics Super Heroes         Mighty Micros  2018
# 619                   Duplo                   NaN  2018
#
#                                        name  pieces  us_price  \
# 0                            Robin vs. Bane    77.0      9.99
# 1                      Ultra Stealth Raider  1093.0    119.99
# 2                              Burj Khalifa   333.0     39.99
# 3                            Lakeside Lodge   368.0     29.99
# 4                      Ultra Stealth Raider  1093.0    119.99
# ..                                      ...     ...       ...
# 615                                  Tiketz    62.0      4.99
# 616                                    Myke    63.0      4.99
# 617  Friends of Heartlake City Girlz 4 Life     NaN     19.99
# 618              The Flash vs. Captain Cold    88.0      9.99
# 619                           Minnie's Café    27.0     19.99
#
#                                              image_url  quantity
# 0    http://images.brickset.com/sets/images/76062-1...         1
# 1    http://images.brickset.com/sets/images/70595-1...         1
# 2    http://images.brickset.com/sets/images/21031-1...         1
# 3    http://images.brickset.com/sets/images/31048-1...         1
# 4    http://images.brickset.com/sets/images/70595-1...         1
# ..                                                 ...       ...
# 615  http://images.brickset.com/sets/images/41556-1...         2
# 616                                                NaN         2
# 617                                                NaN         1
# 618  http://images.brickset.com/sets/images/76063-1...         2
# 619  http://images.brickset.com/sets/images/10830-1...         4
#
# [620 rows x 14 columns]

# %% [markdown]
# ### Exercises
#
# * Answer the following questions using reproducible Python code.
# * For each question, state your answer in a sentence, e.g. "In this sample, the first three common names of purchasers are ...".
# * Note that the answers to all questions are within the context of this particular sample of sales, i.e. you shouldn't make inferences about the population of all Lego sales based on this sample.
#
# -------------
#
# 1.  Describe what you see in the data set (variables, observations, etc)
#
# Variables like lego sets.
#
# 2.  What are the three most common first names of purchasers?
#
# The three most common names are Jackson, Jacob, and Joseph.
#
# 3.  What are the three most common themes of Lego sets purchased?
#
# Star Wars is the most frequent theme.
#
# 4.  Among the most common theme of Lego sets purchased, what is the most common subtheme?
#
# The most popular sub theme for Star Wars is "The force Awakens.
#
# 5.  Create data frames for each of the ages in the following categories: "18 and under", "19 - 25", "26 - 35", "36 - 50", "51 and over". HINT - use masks and create separate data frames -OR- create a new column with these categorical labels (more advanced).
#
#
#
# 6.  Which age group has purchased the highest number of Lego sets.
#
# 7.  Which age group has spent the most money on Legos?
#
# 8.  Which Lego theme has made the most money for Lego? HINT: Simpler than #5, just use a groupby()
#
# 9.  Which area code has spent the most money on Legos? In the US the area code is the first 3 digits of a phone number. HINT: You will need to split the phone number and get just the first three. You decided what to do about reporting the NaNs.
#
# 10.  Come up with a question you want to answer using these data, and write it down. Then, create a data visualization that answers the question, and explain how your visualization answers the question.

# %%
# Q2
DF['first_name'].value_counts()
# Out:
# first_name
# Jackson      13
# Jacob        11
# Joseph       11
# Michael      10
# Lucas         8
#              ..
# Kelly         1
# Katelynn      1
# Stephanie     1
# Miles         1
# Talise        1
# Name: count, Length: 211, dtype: int64

# %%
#Q3
DF['theme'].describe()
# Out:
# count           620
# unique           25
# top       Star Wars
# freq             75
# Name: theme, dtype: object

# %%
#Q4
mask = DF['theme']=='Star Wars'
DF[mask]['subtheme'].value_counts()
# Out:
# subtheme
# The Force Awakens            15
# Buildable Figures            11
# Episode V                    10
# MicroFighters                10
# Battlefront                   7
# Original Content              7
# Episode III                   6
# Seasonal                      3
# Rebels                        3
# Episode IV                    2
# Ultimate Collector Series     1
# Name: count, dtype: int64

# %%
#Q5
age_under_18 = DF[DF["age"] <= 18]
age_19_25 = DF[(DF["age"] >= 19) & (DF["age"] <= 25)]
age_26_35 = DF[(DF["age"] >= 26) & (DF["age"] <= 35)]
age_36_50 = DF[(DF["age"] >= 36) & (DF["age"] <= 50)]
age_51_over = DF[DF["age"] >= 51]

# Optional: print how many people in each group
print(len(age_under_18), len(age_19_25), len(age_26_35), len(age_36_50), len(age_51_over))
# Out:
# 30 129 183 216 62

# %%
#Q6
def categorize_age(age):
    if age <= 18:
        return "18 and under"
    elif age <= 25:
        return "19 - 25"
    elif age <= 35:
        return "26 - 35"
    elif age <= 50:
        return "36 - 50"
    else:
        return "51 and over"

DF["age_group"] = DF["age"].apply(categorize_age)

# %%
#Q7
def categorize_age(age):
    if age <= 18:
        return "18 and under"
    elif age <= 25:
        return "19 - 25"
    elif age <= 35:
        return "26 - 35"
    elif age <= 50:
        return "36 - 50"
    else:
        return "51 and over"

DF["age_group"] = DF["age"].apply(categorize_age)

# %%
#Q8
cols = ['theme','us_price']
DF.groupby(by='theme').sum().sort_values('us_price',ascending=False)
# Out:
#                                                                 first_name  \
# theme
# Star Wars                BryannaAmandaJacobJacobRileyHectorHectorCecili...
# Ninjago                  NeelChelseaToniAmandaHannahHannahErikRileyAust...
# Nexo Knights             KevinNicholasMichelleLucasEricEricCarsonSamant...
# City                     ConnorAmandaTysenJanayCarsonCameronCarolineBin...
# Minecraft                CalebTrevonJanayAmberCeliaDakotahEdenJacksonPe...
# Gear                     JudithNicholasAmandaMckenzieKatherineAnthonyCo...
# Friends                  CalebJacobHannahRebeccaShinaLucasPeggyEricTyri...
# Duplo                    ChelseaChaseChaseAdoriaJaimeTjJordanBrittanySe...
# Elves                    JacobHectorMadelineManuelKatherinePaigeMichael...
# Advanced Models                              ToniKaitlynKatherineElizabeth
# Bionicle                 JacksonSamanthaConnorDavidMichaelColleenNeilPa...
# Marvel Super Heroes      KaylaJakeMadelineTrevorManuelMichaelBrandilynA...
# Technic                  AdamNereaCodyAustinTristinFranciscoKeithMeliss...
# Ghostbusters                                       SamanthaJenniferMelanie
# DC Comics Super Heroes   KimberlyBryannaAmandaJohn'DunaeCarolineSonnyCh...
# Creator                  ChelseaDanielMichelleKaylaLucasTyriiTjReyesMic...
# Architecture             NeelJacksonRebeccaShinaDemetriBrittanyKatrinaJ...
# The Angry Birds Movie    KatherineKaylaDakotaMatthewKatieKareenaAustinL...
# Dimensions               ConnorDakotaJoshuaKatieBrandonMichaelJohn JayA...
# Mixels                   ConnorDanielJacksonRebeccaAnthonyLucasLucasLuc...
# Disney Princess          ShinaLucasJakeJanayTrevorColleenBrandilynBrand...
# Ideas                                                       BrendenTynecia
# Classic                                                          Christina
# Seasonal                                              MichaelSerenaRachael
# Collectable Minifigures                                DaianairaSethKeyana
#
#                                                                  last_name  \
# theme
# Star Wars                WelshTronnierNzabanitaNzabanitaOttCollinsColli...
# Ninjago                  GarvinBouchardBorisonTronnierDrews StunkelDrew...
# Nexo Knights             CruzBelfageouaUguccioniMontoyaBenallyBenallyAr...
# City                     BrownTronnierBanda-ChavezGienappAragonRodrigue...
# Minecraft                Garcia-WidemanThanhGienappTerwilligerFoleyBaca...
# Gear                     WebbBelfageouaTronnierCherryHogueKiyotakeFourz...
# Friends                  Garcia-WidemanNzabanitaDrews StunkelDuvalHegar...
# Duplo                    BouchardFortenberryFortenberryHammondRideoutAg...
# Elves                    NzabanitaCollinsCastorWilkersonBeckWagnerCruzB...
# Advanced Models                                  BorisonDegeerBeckRoemmich
# Bionicle                 MartinezHaberlandPadillaCabralWilliamsGalleyGa...
# Marvel Super Heroes      RushMontes AlvarezCastorPerezWilkersonHernande...
# Technic                  AlbornozFeldmanGonzalesAtencioMarcySmithAtwood...
# Ghostbusters                                          HaberlandDanaRollert
# DC Comics Super Heroes   BecksteadWelshMusickHigginsHolsteinSmithWillia...
# Creator                  BouchardHurstUguccioniRushJimenez-DominguezBlo...
# Architecture             GarvinMartinezDuvalHegartyDoMclellanClymanO'Bo...
# The Angry Birds Movie    HogueRushKloppSandovalEveringHagarAtencioFaulk...
# Dimensions               BrownKloppReyesEveringLopezCruzGriegoGorrellPa...
# Mixels                   BrownHurstMartinezDuvalKiyotakeMontoyaJimenez-...
# Disney Princess          HegartyJimenez-DominguezMontes AlvarezGienappP...
# Ideas                                                       TrujilloKramer
# Classic                                                           Williams
# Seasonal                                          WilliamsBartkowiakTilley
# Collectable Minifigures                                   JosephFoleyLafay
#
#                           age  \
# theme
# Star Wars                2725
# Ninjago                  1413
# Nexo Knights             2103
# City                     1609
# Minecraft                 348
# Gear                     2016
# Friends                  1435
# Duplo                    1220
# Elves                     682
# Advanced Models           141
# Bionicle                 1030
# Marvel Super Heroes       637
# Technic                   373
# Ghostbusters               90
# DC Comics Super Heroes    715
# Creator                   787
# Architecture              327
# The Angry Birds Movie     352
# Dimensions                634
# Mixels                   1904
# Disney Princess           495
# Ideas                      51
# Classic                    39
# Seasonal                   73
# Collectable Minifigures   102
#
#                                                               phone_number  \
# theme
# Star Wars                317-555-7477339-555-2572339-555-2572517-555-20...
# Ninjago                  819-555-3189284-555-4560317-555-7477339-555-63...
# Nexo Knights             947-555-7946606-555-4814616-555-2269418-555-36...
# City                     516-555-4310317-555-7477774-555-2102325-555-19...
# Minecraft                907-555-9236774-555-2102626-555-5321979-555-11...
# Gear                     917-555-7417606-555-4814317-555-7477336-555-92...
# Friends                  907-555-9236339-555-2572339-555-6320908-555-40...
# Duplo                    205-555-3704205-555-3704712-555-6781913-555-51...
# Elves                    339-555-2572340-555-2508450-555-9877441-555-36...
# Advanced Models           284-555-4560316-555-7890209-555-7105502-555-4381
# Bionicle                 250-555-1732705-555-1457441-555-6534415-555-86...
# Marvel Super Heroes      281-555-9341603-555-6881450-555-9877878-555-51...
# Technic                  418-555-2486423-555-9631973-555-3236225-555-73...
# Ghostbusters                                      705-555-1457956-555-9719
# DC Comics Super Heroes   216-555-2549878-555-7113813-555-5561318-555-78...
# Creator                  251-555-0845281-555-9341712-555-0459784-555-71...
# Architecture             819-555-3189250-555-1732908-555-4029868-555-18...
# The Angry Birds Movie    289-555-4928281-555-9341970-555-9320671-555-70...
# Dimensions               516-555-4310970-555-9320251-555-5985882-555-72...
# Mixels                   516-555-4310251-555-0845250-555-1732908-555-40...
# Disney Princess          868-555-1868712-555-0459603-555-6881774-555-21...
# Ideas                                             928-555-1076778-555-0036
# Classic                                                       541-555-5085
# Seasonal                              936-555-2974305-555-2377806-555-8594
# Collectable Minifigures                           714-555-9762786-555-6090
#
#                           set_id  \
# theme
# Star Wars                1879900
# Ninjago                   961559
# Nexo Knights             1608795
# City                     1123606
# Minecraft                 230504
# Gear                     1425979
# Friends                  1040452
# Duplo                     869884
# Elves                     553042
# Advanced Models            99976
# Bionicle                  849151
# Marvel Super Heroes       476761
# Technic                   248344
# Ghostbusters               76933
# DC Comics Super Heroes    548230
# Creator                   618938
# Architecture              246636
# The Angry Birds Movie     282271
# Dimensions                443713
# Mixels                   1394276
# Disney Princess           370483
# Ideas                      51316
# Classic                    24995
# Seasonal                   74963
# Collectable Minifigures    76782
#
#                                                                     number  \
# theme
# Star Wars                7513875139751337515175126751167509875157751307...
# Ninjago                  7059570595705958535437059070593705897060470600...
# Nexo Knights             7033570327703107033070316703197031970333703137...
# City                     6011260118601083034930347303476010960118601133...
# Minecraft                    211272112821128211272112821127211282112721128
# Gear                     5005059853549500461285350585355585356885351985...
# Friends                  4111541117411194111441135411144111941122411204...
# Duplo                    1083110801108091083010818108301080710818108041...
# Elves                    4117241172411784117441178411764117241172411794...
# Advanced Models                                       10251102511025110251
# Bionicle                 7130471313713107130971307713007130771309713057...
# Marvel Super Heroes      7606576066760597604876066760477604776066760517...
# Technic                  4205042049420524204842044420464204842048420474...
# Ghostbusters                                               758287582775828
# DC Comics Super Heroes   7606276062760547604676053760537604476061760447...
# Creator                  3104831048310463104631043310443104031045310413...
# Architecture             2103121031210282102821031210262102721026210272...
# The Angry Birds Movie    7582275824758227582275821758257582175824758267...
# Dimensions               7123071235712387122871241712387122971228712357...
# Mixels                   4157341558415594157341568415554157341558415724...
# Disney Princess          4114241140411404114041069411414106941140411404...
# Ideas                                                           2130521305
# Classic                                                              10702
# Seasonal                                                   402024020140202
# Collectable Minifigures                                    710117101171011
#
#                                                                   subtheme  \
# theme
# Star Wars                Episode VThe Force AwakensBattlefrontEpisode I...
# Ninjago                  Rise of the VillainsRise of the VillainsRise o...
# Nexo Knights             UltimateUltimateUltimateUltimateUltimateUltima...
# City                     FireTrafficFireFireFireFireTrafficTrafficFireF...
# Minecraft                Minifig-scaleMinifig-scaleMinifig-scaleMinifig...
# Gear                     Video Games/PS3Key Chains/FriendsWatches/Clock...
# Friends                  Pop StarPartyPop StarPartyAdventure CampAdvent...
# Duplo                    Mickey Mouse ClubhouseMickey Mouse ClubhouseMi...
# Elves                                                                    0
# Advanced Models          Modular BuildingsModular BuildingsModular Buil...
# Bionicle                 CompanionsReboot VillainsReboot VillainsToaToa...
# Marvel Super Heroes      Mighty MicrosMighty MicrosUltimate Spider-ManA...
# Technic                                                                  0
# Ghostbusters                                                  RebootReboot
# DC Comics Super Heroes   Mighty MicrosMighty MicrosBatmanBatman v Super...
# Creator                                                                  0
# Architecture             SkylinesSkylinesSkylinesSkylinesSkylinesSkylin...
# The Angry Birds Movie                                                    0
# Dimensions               Fun PackLevel PackFun PackLevel PackFun PackFu...
# Mixels                   Series 9Series 7Series 7Series 9Series 8Series...
# Disney Princess          Palace PetsPalace PetsPalace PetsPalace PetsPa...
# Ideas                                                                    0
# Classic                                                                  0
# Seasonal                                       EasterValentine's DayEaster
# Collectable Minifigures                        Series 15Series 15Series 15
#
#                            year  \
# theme
# Star Wars                151350
# Ninjago                   76684
# Nexo Knights             129152
# City                      90810
# Minecraft                 18162
# Gear                     110990
# Friends                   84756
# Duplo                     70630
# Elves                     44396
# Advanced Models            8072
# Bionicle                  68612
# Marvel Super Heroes       38342
# Technic                   20180
# Ghostbusters               6054
# DC Comics Super Heroes    44396
# Creator                   50450
# Architecture              20180
# The Angry Birds Movie     22198
# Dimensions                36324
# Mixels                   110990
# Disney Princess           30270
# Ideas                      4036
# Classic                    2018
# Seasonal                   6054
# Collectable Minifigures    6054
#
#                                                                       name  \
# theme
# Star Wars                Hoth AttackBattle on TakodanaRebel Alliance Ba...
# Ninjago                  Ultra Stealth RaiderUltra Stealth RaiderUltra ...
# Nexo Knights             Ultimate LavariaThe King's MechKnighton Battle...
# City                     Fire EngineGarbage TruckFire Response UnitSpor...
# Minecraft                The FortressThe VillageThe VillageThe Fortress...
# Gear                     Marvel Avengers PS3 Video GameMia Key ChainLuc...
# Friends                  Emma's Creative WorkshopPop Star TV StudioHear...
# Duplo                    My First CaterpillarBaby AnimalsPolice PatrolM...
# Elves                    The Water Dragon AdventureThe Water Dragon Adv...
# Advanced Models                   Brick BankBrick BankBrick BankBrick Bank
# Bionicle                 Terak - Creature of EarthLava BeastUmarak the ...
# Marvel Super Heroes      Captain America vs. Red SkullHulk vs. UltronSp...
# Technic                  Drag RacerMine LoaderHeavy Lift HelicopterRace...
# Ghostbusters             Ghostbusters Ecto-1 & Ecto-2Firehouse Headquar...
# DC Comics Super Heroes   Robin vs. BaneRobin vs. BaneBatman: Scarecrow ...
# Creator                  Lakeside LodgeLakeside LodgeFast CarFast CarCh...
# Architecture             Burj KhalifaBurj KhalifaNew York CityNew York ...
# The Angry Birds Movie    Piggy Plane AttackPig City TeardownPiggy Plane...
# Dimensions               Fun Pack: Doc BrownLevel Pack: Midway ArcadeFu...
# Mixels                   SweepzMixadelPaladumSweepzLewtBustoSweepzMixad...
# Disney Princess          Palace Pets Royal CastleDaisy's Beauty SalonDa...
# Ideas                                                             MazeMaze
# Classic                                              Creative Building Set
# Seasonal                     Easter ChickValentine's Cupid DogEaster Chick
# Collectable Minifigures  LEGO Minifigures - Series 15 - Sealed BoxLEGO ...
#
#                           pieces  us_price  \
# theme
# Star Wars                23440.0   2842.25
# Ninjago                  16905.0   1649.62
# Nexo Knights             16130.0   1569.36
# City                     10691.0   1476.55
# Minecraft                    0.0   1439.91
# Gear                         0.0   1056.45
# Friends                  10038.0    924.58
# Duplo                     1260.0    854.65
# Elves                     9091.0    809.78
# Advanced Models           9520.0    679.96
# Bionicle                  3904.0    549.66
# Marvel Super Heroes       5351.0    539.81
# Technic                   4315.0    492.90
# Ghostbusters              4634.0    469.97
# DC Comics Super Heroes    4136.0    450.78
# Creator                   4997.0    409.75
# Architecture              3486.0    389.90
# The Angry Birds Movie     3457.0    375.89
# Dimensions                1234.0    369.82
# Mixels                    3493.0    274.45
# Disney Princess           1493.0    167.85
# Ideas                     1538.0    139.98
# Classic                    583.0     29.99
# Seasonal                   372.0     29.97
# Collectable Minifigures      0.0     11.97
#
#                                                                  image_url  \
# theme
# Star Wars                http://images.brickset.com/sets/images/75138-1...
# Ninjago                  http://images.brickset.com/sets/images/70595-1...
# Nexo Knights             http://images.brickset.com/sets/images/70335-1...
# City                     http://images.brickset.com/sets/images/60112-1...
# Minecraft                http://images.brickset.com/sets/images/21127-1...
# Gear                     http://images.brickset.com/sets/images/5005059...
# Friends                  http://images.brickset.com/sets/images/41115-1...
# Duplo                    http://images.brickset.com/sets/images/10831-1...
# Elves                    http://images.brickset.com/sets/images/41172-1...
# Advanced Models          http://images.brickset.com/sets/images/10251-1...
# Bionicle                 http://images.brickset.com/sets/images/71304-1...
# Marvel Super Heroes      http://images.brickset.com/sets/images/76065-1...
# Technic                  http://images.brickset.com/sets/images/42050-1...
# Ghostbusters             http://images.brickset.com/sets/images/75828-1...
# DC Comics Super Heroes   http://images.brickset.com/sets/images/76062-1...
# Creator                  http://images.brickset.com/sets/images/31048-1...
# Architecture             http://images.brickset.com/sets/images/21031-1...
# The Angry Birds Movie    http://images.brickset.com/sets/images/75822-1...
# Dimensions               http://images.brickset.com/sets/images/71230-1...
# Mixels                   http://images.brickset.com/sets/images/41558-1...
# Disney Princess          http://images.brickset.com/sets/images/41142-1...
# Ideas                                                                    0
# Classic                  http://images.brickset.com/sets/images/10702-1...
# Seasonal                 http://images.brickset.com/sets/images/40201-1...
# Collectable Minifigures  http://images.brickset.com/sets/images/71011-1...
#
#                          quantity
# theme
# Star Wars                     117
# Ninjago                        59
# Nexo Knights                   93
# City                           65
# Minecraft                      10
# Gear                           79
# Friends                        56
# Duplo                          50
# Elves                          28
# Advanced Models                 5
# Bionicle                       46
# Marvel Super Heroes            30
# Technic                        12
# Ghostbusters                    5
# DC Comics Super Heroes         35
# Creator                        35
# Architecture                   15
# The Angry Birds Movie          13
# Dimensions                     24
# Mixels                         83
# Disney Princess                20
# Ideas                           3
# Classic                         1
# Seasonal                        4
# Collectable Minifigures         3

# %%
#Q9
DF['area_code'] = DF['phone_number'].astype(str).str.extract(r'(\d{3})')

# %%
#Q10
avg_spending_by_age = DF.groupby("age_group")["amount_spent"].mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 2
#       1 #Q10
# ----> 2 avg_spending_by_age = DF.groupby("age_group")["amount_spent"].mean().reset_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# --> 244         raise KeyError(f"Column not found: {key}")
#     245     ndim = self.obj[key].ndim
#     246     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: amount_spent'

# %% [markdown]
# ## Essay Response
#
# Give a brief report on what you are reading and what you have learned so far. If you chose your own articles please insert a link to the articles. If you chose a book, please give the book title and author.
#
# 1. What drew you to the book/articles
# 2. What have you learned so far.
#
# eg. In the first chapter of the book the author talks about..... or My first article discusses..... or I disagree with what the author is saying so far.... or I really like what I am learning about because....

# %% [markdown]
# One of my favorite articles from this article in the book "Data Feminism," is when they took a deep dive into the bias and gap in clothing. More specifically women's vs. men's clothing being biased based on price
